# %% [markdown]
# #### `Import Libraries`

# %%
import os
import re
import hashlib
import cv2
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers,Model,callbacks,optimizers,metrics
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

# %% [markdown]
# #### `Read Data`

# %%
DATASET_DIR = "Shop DataSet"

non_shop_lifters_dir = os.path.join(DATASET_DIR, "non shop lifters")
shop_lifters_dir = os.path.join(DATASET_DIR, "shop lifters")

# %%
def delete_all_suffix_1_files(folder_path):
    print(f"\nChecking folder: {folder_path}")

    video_files = [f for f in os.listdir(folder_path) if f.lower().endswith(".mp4")]
    to_delete = [f for f in video_files if re.search(r"_1\.mp4$", f, re.IGNORECASE)]

    print(f"Files to delete: {len(to_delete)}")

    for f in to_delete:
        file_path = os.path.join(folder_path, f)
        try:
            os.remove(file_path)
            print(f"Deleted: {f}")
        except Exception as e:
            print(f"Error deleting {file_path}: {e}")

# %%
delete_all_suffix_1_files(non_shop_lifters_dir)
delete_all_suffix_1_files(shop_lifters_dir)
# Out:
# Checking folder: Shop DataSet\non shop lifters
# Files to delete: 220
# Deleted: shop_lifter_n_0_1.mp4
# Deleted: shop_lifter_n_1.mp4
# Deleted: shop_lifter_n_100_1.mp4
# Deleted: shop_lifter_n_101_1.mp4
# Deleted: shop_lifter_n_102_1.mp4
# Deleted: shop_lifter_n_103_1.mp4
# Deleted: shop_lifter_n_104_1.mp4
# Deleted: shop_lifter_n_105_1.mp4
# Deleted: shop_lifter_n_106_1.mp4
# Deleted: shop_lifter_n_107_1.mp4
# Deleted: shop_lifter_n_108_1.mp4
# Deleted: shop_lifter_n_109_1.mp4
# Deleted: shop_lifter_n_10_1.mp4
# Deleted: shop_lifter_n_110_1.mp4
# Deleted: shop_lifter_n_111_1.mp4
# Deleted: shop_lifter_n_112_1.mp4
# Deleted: shop_lifter_n_113_1.mp4
# Deleted: shop_lifter_n_114_1.mp4
# Deleted: shop_lifter_n_115_1.mp4
# Deleted: shop_lifter_n_116_1.mp4
# Deleted: shop_lifter_n_117_1.mp4
# Deleted: shop_lifter_n_118_1.mp4
# Deleted: shop_lifter_n_119_1.mp4
# Deleted: shop_lifter_n_11_1.mp4
# Deleted: shop_lifter_n_120_1.mp4
# Deleted: shop_lifter_n_121_1.mp4
# Deleted: shop_lifter_n_122_1.mp4
# Deleted: shop_lifter_n_123_1.mp4
# Deleted: shop_lifter_n_124_1.mp4
# Deleted: shop_lifter_n_125_1.mp4
# Deleted: shop_lifter_n_126_1.mp4
# Deleted: shop_lifter_n_127_1.mp4
# Deleted: shop_lifter_n_128_1.mp4
# Deleted: shop_lifter_n_129_1.mp4
# Deleted: shop_lifter_n_12_1.mp4
# Deleted: shop_lifter_n_130_1.mp4
# Deleted: shop_lifter_n_131_1.mp4
# Deleted: shop_lifter_n_132_1.mp4
# Deleted: shop_lifter_n_133_1.mp4
# Deleted: shop_lifter_n_134_1.mp4
# Deleted: shop_lifter_n_135_1.mp4
# Deleted: shop_lifter_n_136_1.mp4
# Deleted: shop_lifter_n_137_1.mp4
# Deleted: shop_lifter_n_138_1.mp4
# Deleted: shop_lifter_n_139_1.mp4
# Deleted: shop_lifter_n_13_1.mp4
# Deleted: shop_lifter_n_140_1.mp4
# Deleted: shop_lifter_n_141_1.mp4
# Deleted: shop_lifter_n_142_1.mp4
# Deleted: shop_lifter_n_143_1.mp4
# Deleted: shop_lifter_n_144_1.mp4
# Deleted: shop_lifter_n_145_1.mp4
# Deleted: shop_lifter_n_146_1.mp4
# Deleted: shop_lifter_n_147_1.mp4
# Deleted: shop_lifter_n_148_1.mp4
# Deleted: shop_lifter_n_149_1.mp4
# Deleted: shop_lifter_n_14_1.mp4
# Deleted: shop_lifter_n_150_1.mp4
# Deleted: shop_lifter_n_151_1.mp4
# Deleted: shop_lifter_n_152_1.mp4
# Deleted: shop_lifter_n_153_1.mp4
# Deleted: shop_lifter_n_154_1.mp4
# Deleted: shop_lifter_n_155_1.mp4
# Deleted: shop_lifter_n_156_1.mp4
# Deleted: shop_lifter_n_157_1.mp4
# Deleted: shop_lifter_n_158_1.mp4
# Deleted: shop_lifter_n_159_1.mp4
# Deleted: shop_lifter_n_15_1.mp4
# Deleted: shop_lifter_n_160_1.mp4
# Deleted: shop_lifter_n_161_1.mp4
# Deleted: shop_lifter_n_162_1.mp4
# Deleted: shop_lifter_n_163_1.mp4
# Deleted: shop_lifter_n_164_1.mp4
# Deleted: shop_lifter_n_165_1.mp4
# Deleted: shop_lifter_n_166_1.mp4
# Deleted: shop_lifter_n_167_1.mp4
# Deleted: shop_lifter_n_168_1.mp4
# Deleted: shop_lifter_n_169_1.mp4
# Deleted: shop_lifter_n_16_1.mp4
# Deleted: shop_lifter_n_170_1.mp4
# Deleted: shop_lifter_n_172_1.mp4
# Deleted: shop_lifter_n_173_1.mp4
# Deleted: shop_lifter_n_174_1.mp4
# Deleted: shop_lifter_n_175_1.mp4
# Deleted: shop_lifter_n_176_1.mp4
# Deleted: shop_lifter_n_177_1.mp4
# Deleted: shop_lifter_n_178_1.mp4
# Deleted: shop_lifter_n_179_1.mp4
# Deleted: shop_lifter_n_17_1.mp4
# Deleted: shop_lifter_n_180_1.mp4
# Deleted: shop_lifter_n_181_1.mp4
# Deleted: shop_lifter_n_182_1.mp4
# Deleted: shop_lifter_n_183_1.mp4
# Deleted: shop_lifter_n_184_1.mp4
# Deleted: shop_lifter_n_185_1.mp4
# Deleted: shop_lifter_n_186_1.mp4
# Deleted: shop_lifter_n_187_1.mp4
# Deleted: shop_lifter_n_188_1.mp4
# Deleted: shop_lifter_n_189_1.mp4
# Deleted: shop_lifter_n_18_1.mp4
# Deleted: shop_lifter_n_190_1.mp4
# Deleted: shop_lifter_n_191_1.mp4
# Deleted: shop_lifter_n_192_1.mp4
# Deleted: shop_lifter_n_193_1.mp4
# Deleted: shop_lifter_n_194_1.mp4
# Deleted: shop_lifter_n_195_1.mp4
# Deleted: shop_lifter_n_196_1.mp4
# Deleted: shop_lifter_n_197_1.mp4
# Deleted: shop_lifter_n_198_1.mp4
# Deleted: shop_lifter_n_199_1.mp4
# Deleted: shop_lifter_n_19_1.mp4
# Deleted: shop_lifter_n_1_1.mp4
# Deleted: shop_lifter_n_200_1.mp4
# Deleted: shop_lifter_n_201_1.mp4
# Deleted: shop_lifter_n_202_1.mp4
# Deleted: shop_lifter_n_203_1.mp4
# Deleted: shop_lifter_n_204_1.mp4
# Deleted: shop_lifter_n_205_1.mp4
# Deleted: shop_lifter_n_206_1.mp4
# Deleted: shop_lifter_n_207_1.mp4
# Deleted: shop_lifter_n_208_1.mp4
# Deleted: shop_lifter_n_209_1.mp4
# Deleted: shop_lifter_n_20_1.mp4
# Deleted: shop_lifter_n_210_1.mp4
# Deleted: shop_lifter_n_211_1.mp4
# Deleted: shop_lifter_n_212_1.mp4
# Deleted: shop_lifter_n_213_1.mp4
# Deleted: shop_lifter_n_214_1.mp4
# Deleted: shop_lifter_n_215_1.mp4
# Deleted: shop_lifter_n_216_1.mp4
# Deleted: shop_lifter_n_217_1.mp4
# Deleted: shop_lifter_n_218_1.mp4
# Deleted: shop_lifter_n_21_1.mp4
# Deleted: shop_lifter_n_22_1.mp4
# Deleted: shop_lifter_n_23_1.mp4
# Deleted: shop_lifter_n_24_1.mp4
# Deleted: shop_lifter_n_25_1.mp4
# Deleted: shop_lifter_n_26_1.mp4
# Deleted: shop_lifter_n_27_1.mp4
# Deleted: shop_lifter_n_28_1.mp4
# Deleted: shop_lifter_n_29_1.mp4
# Deleted: shop_lifter_n_2_1.mp4
# Deleted: shop_lifter_n_30_1.mp4
# Deleted: shop_lifter_n_31_1.mp4
# Deleted: shop_lifter_n_32_1.mp4
# Deleted: shop_lifter_n_33_1.mp4
# Deleted: shop_lifter_n_34_1.mp4
# Deleted: shop_lifter_n_35_1.mp4
# Deleted: shop_lifter_n_36_1.mp4
# Deleted: shop_lifter_n_37_1.mp4
# Deleted: shop_lifter_n_38_1.mp4
# Deleted: shop_lifter_n_39_1.mp4
# Deleted: shop_lifter_n_3_1.mp4
# Deleted: shop_lifter_n_40_1.mp4
# Deleted: shop_lifter_n_41_1.mp4
# Deleted: shop_lifter_n_42_1.mp4
# Deleted: shop_lifter_n_43_1.mp4
# Deleted: shop_lifter_n_44_1.mp4
# Deleted: shop_lifter_n_45_1.mp4
# Deleted: shop_lifter_n_46_1.mp4
# Deleted: shop_lifter_n_47_1.mp4
# Deleted: shop_lifter_n_48_1.mp4
# Deleted: shop_lifter_n_49_1.mp4
# Deleted: shop_lifter_n_4_1.mp4
# Deleted: shop_lifter_n_50_1.mp4
# Deleted: shop_lifter_n_51_1.mp4
# Deleted: shop_lifter_n_52_1.mp4
# Deleted: shop_lifter_n_53_1.mp4
# Deleted: shop_lifter_n_54_1.mp4
# Deleted: shop_lifter_n_55_1.mp4
# Deleted: shop_lifter_n_56_1.mp4
# Deleted: shop_lifter_n_57_1.mp4
# Deleted: shop_lifter_n_58_1.mp4
# Deleted: shop_lifter_n_59_1.mp4
# Deleted: shop_lifter_n_5_1.mp4
# Deleted: shop_lifter_n_60_1.mp4
# Deleted: shop_lifter_n_61_1.mp4
# Deleted: shop_lifter_n_62_1.mp4
# Deleted: shop_lifter_n_63_1.mp4
# Deleted: shop_lifter_n_64_1.mp4
# Deleted: shop_lifter_n_65_1.mp4
# Deleted: shop_lifter_n_66_1.mp4
# Deleted: shop_lifter_n_67_1.mp4
# Deleted: shop_lifter_n_68_1.mp4
# Deleted: shop_lifter_n_69_1.mp4
# Deleted: shop_lifter_n_6_1.mp4
# Deleted: shop_lifter_n_70_1.mp4
# Deleted: shop_lifter_n_71_1.mp4
# Deleted: shop_lifter_n_72_1.mp4
# Deleted: shop_lifter_n_73_1.mp4
# Deleted: shop_lifter_n_74_1.mp4
# Deleted: shop_lifter_n_75_1.mp4
# Deleted: shop_lifter_n_76_1.mp4
# Deleted: shop_lifter_n_77_1.mp4
# Deleted: shop_lifter_n_78_1.mp4
# Deleted: shop_lifter_n_79_1.mp4
# Deleted: shop_lifter_n_7_1.mp4
# Deleted: shop_lifter_n_80_1.mp4
# Deleted: shop_lifter_n_81_1.mp4
# Deleted: shop_lifter_n_82_1.mp4
# Deleted: shop_lifter_n_83_1.mp4
# Deleted: shop_lifter_n_84_1.mp4
# Deleted: shop_lifter_n_85_1.mp4
# Deleted: shop_lifter_n_86_1.mp4
# Deleted: shop_lifter_n_87_1.mp4
# Deleted: shop_lifter_n_88_1.mp4
# Deleted: shop_lifter_n_89_1.mp4
# Deleted: shop_lifter_n_8_1.mp4
# Deleted: shop_lifter_n_90_1.mp4
# Deleted: shop_lifter_n_91_1.mp4
# Deleted: shop_lifter_n_92_1.mp4
# Deleted: shop_lifter_n_93_1.mp4
# Deleted: shop_lifter_n_94_1.mp4
# Deleted: shop_lifter_n_95_1.mp4
# Deleted: shop_lifter_n_96_1.mp4
# Deleted: shop_lifter_n_97_1.mp4
# Deleted: shop_lifter_n_98_1.mp4
# Deleted: shop_lifter_n_99_1.mp4
# Deleted: shop_lifter_n_9_1.mp4
# Deleted: videppppsss_1.mp4
#
# Checking folder: Shop DataSet\shop lifters
# Files to delete: 5
# Deleted: shop_lifter_1.mp4
# Deleted: videppppsss_1.mp4
# Deleted: videyyyyyynnnnnnzzzzzyyyss_1.mp4
# Deleted: videyyyyyyyyyss_1.mp4
# Deleted: videyyyyyyzzzzzyyyss_1.mp4

# %%
def count_videos(folder_path):
    video_files = [f for f in os.listdir(folder_path) if f.lower().endswith(".mp4")]
    return len(video_files)

non_count = count_videos(non_shop_lifters_dir)
shop_count = count_videos(shop_lifters_dir)

print("non shop lifters videos:", non_count)
print("shop lifters videos    :", shop_count)
print("Total videos           :", non_count + shop_count)
# Out:
# non shop lifters videos: 311
# shop lifters videos    : 319
# Total videos           : 630

# %%
CLASS_NAMES = ["non shop lifters", "shop lifters"]
CLASS_TO_LABEL = {
    "non shop lifters": 0,
    "shop lifters": 1
}

SEQ_LEN = 32
IMG_SIZE = 128
BATCH_SIZE = 4
SEED = 42

# %% [markdown]
# #### `Understand Data`

# %%
def collect_video_metadata(dataset_dir, class_names):
    records = []

    for cls in class_names:
        class_dir = os.path.join(dataset_dir, cls)

        if not os.path.exists(class_dir):
            print(f"Folder not found: {class_dir}")
            continue

        for file_name in os.listdir(class_dir):
            file_path = os.path.join(class_dir, file_name)

            if not os.path.isfile(file_path):
                continue

            cap = cv2.VideoCapture(file_path)

            frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            fps = cap.get(cv2.CAP_PROP_FPS)
            width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

            duration_sec = frames / fps if fps and fps > 0 else 0

            records.append({
                "class": cls,
                "label": CLASS_TO_LABEL[cls],
                "file": file_name,
                "path": file_path,
                "frames": frames,
                "fps": fps,
                "width": width,
                "height": height,
                "duration_sec": duration_sec
            })

            cap.release()

    return pd.DataFrame(records)

df = collect_video_metadata(DATASET_DIR, CLASS_NAMES)
print(df.shape)
df.head()
# Out:
# (630, 9)
#               class  label                   file  \
# 0  non shop lifters      0    shop_lifter_n_0.mp4
# 1  non shop lifters      0   shop_lifter_n_10.mp4
# 2  non shop lifters      0  shop_lifter_n_100.mp4
# 3  non shop lifters      0  shop_lifter_n_101.mp4
# 4  non shop lifters      0  shop_lifter_n_102.mp4
#
#                                                 path  frames   fps  width  \
# 0  Shop DataSet\non shop lifters\shop_lifter_n_0.mp4     450  25.0    704
# 1  Shop DataSet\non shop lifters\shop_lifter_n_10...     475  25.0    704
# 2  Shop DataSet\non shop lifters\shop_lifter_n_10...     400  25.0    704
# 3  Shop DataSet\non shop lifters\shop_lifter_n_10...     300  25.0    704
# 4  Shop DataSet\non shop lifters\shop_lifter_n_10...     275  25.0    704
#
#    height  duration_sec
# 0     576          18.0
# 1     576          19.0
# 2     576          16.0
# 3     576          12.0
# 4     576          11.0

# %%
print(df["class"].value_counts())
print()
print(df.describe(include="all"))
# Out:
# class
# shop lifters        319
# non shop lifters    311
# Name: count, dtype: int64
#
#                class       label                file  \
# count            630  630.000000                 630
# unique             2         NaN                 575
# top     shop lifters         NaN  videppppsss_40.mp4
# freq             319         NaN                   2
# mean             NaN    0.506349                 NaN
# std              NaN    0.500357                 NaN
# min              NaN    0.000000                 NaN
# 25%              NaN    0.000000                 NaN
# 50%              NaN    1.000000                 NaN
# 75%              NaN    1.000000                 NaN
# max              NaN    1.000000                 NaN
#
#                                                      path       frames  \
# count                                                 630   630.000000
# unique                                                630          NaN
# top     Shop DataSet\shop lifters\videyyyyyyzzzzzyyyss...          NaN
# freq                                                    1          NaN
# mean                                                  NaN   324.233333
# std                                                   NaN   109.121413
# min                                                   NaN    75.000000
# 25%                                                   NaN   250.000000
# 50%                                                   NaN   323.000000
# 75%                                                   NaN   375.000000
# max                                                   NaN  1850.000000
#
#                fps  width  height  duration_sec
# count   630.000000  630.0   630.0    630.000000
# unique         NaN    NaN     NaN           NaN
# top            NaN    NaN     NaN           NaN
# freq           NaN    NaN     NaN           NaN
# mean     24.936587  704.0   576.0     13.001922
# std       0.100065    0.0     0.0      4.369965
# min      24.750000  704.0   576.0      3.000000
# 25%      24.830000  704.0   576.0     10.020202
# 50%      25.000000  704.0   576.0     13.000000
# 75%      25.000000  704.0   576.0     15.022151
# max      25.000000  704.0   576.0     74.000000

# %% [markdown]
# #### `Visualization`

# %%
plt.figure(figsize=(6,4))
df["class"].value_counts().plot(kind="bar")
plt.title("Class Distribution")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.hist(df["frames"], bins=20)
plt.title("Frames Distribution")
plt.xlabel("Number of Frames")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.hist(df["duration_sec"], bins=20)
plt.title("Video Duration Distribution")
plt.xlabel("Duration (seconds)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.hist(df["fps"], bins=20)
plt.title("FPS Distribution")
plt.xlabel("FPS")
plt.ylabel("Count")
plt.show()

# %%
train_df, temp_df = train_test_split(
    df,
    test_size=0.30,
    random_state=SEED,
    stratify=df["label"]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    random_state=SEED,
    stratify=temp_df["label"]
)

train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print("Train:", train_df.shape)
print("Val  :", val_df.shape)
print("Test :", test_df.shape)
# Out:
# Train: (441, 9)
# Val  : (94, 9)
# Test : (95, 9)

# %%
def show_sample_frames(video_path, num_frames=6):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    if total_frames <= 0:
        print("Cannot read video.")
        cap.release()
        return

    indices = np.linspace(0, total_frames - 1, num_frames).astype(int)

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        success, frame = cap.read()
        if success:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame)

    cap.release()

    plt.figure(figsize=(15, 4))
    for i, frame in enumerate(frames):
        plt.subplot(1, len(frames), i + 1)
        plt.imshow(frame)
        plt.title(f"Frame {indices[i]}")
        plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
sample_path = df.iloc[0]["path"]
print(sample_path)
show_sample_frames(sample_path, num_frames=6)
# Out:
# Shop DataSet\non shop lifters\shop_lifter_n_0.mp4

# %% [markdown]
# #### `Preprocessing`

# %%
def uniform_frame_sampling(video_path, seq_len=32, img_size=128):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    if total_frames <= 0:
        cap.release()
        return np.zeros((seq_len, img_size, img_size, 3), dtype=np.float32)

    indices = np.linspace(0, total_frames - 1, seq_len).astype(int)

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        success, frame = cap.read()

        if not success:
            frame = np.zeros((img_size, img_size, 3), dtype=np.uint8)
        else:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = cv2.resize(frame, (img_size, img_size))

        frames.append(frame)

    cap.release()
    frames = np.array(frames, dtype=np.float32)
    return frames

# %%
def augment_video_frames(frames):
    augmented = frames.copy()

    if random.random() < 0.5:
        augmented = np.array([cv2.flip(f, 1) for f in augmented])

    if random.random() < 0.5:
        factor = random.uniform(0.8, 1.2)
        augmented = np.clip(augmented * factor, 0, 255)

    if random.random() < 0.3:
        angle = random.uniform(-10, 10)
        h, w = augmented[0].shape[:2]
        M = cv2.getRotationMatrix2D((w // 2, h // 2), angle, 1.0)

        rotated_frames = []
        for f in augmented:
            rotated = cv2.warpAffine(
                f, M, (w, h),
                borderMode=cv2.BORDER_REFLECT_101
            )
            rotated_frames.append(rotated)

        augmented = np.array(rotated_frames)

    return augmented.astype(np.float32)

# %%
def show_original_vs_augmented(video_path, seq_len=32, img_size=128):
    original = uniform_frame_sampling(video_path, seq_len=seq_len, img_size=img_size)
    augmented = augment_video_frames(original)

    plt.figure(figsize=(16, 4))
    for i in range(seq_len):
        plt.subplot(2, seq_len, i + 1)
        plt.imshow(original[i].astype(np.uint8))
        plt.axis("off")
        if i == 0:
            plt.ylabel("Original", fontsize=12)

        plt.subplot(2, seq_len, seq_len + i + 1)
        plt.imshow(augmented[i].astype(np.uint8))
        plt.axis("off")
        if i == 0:
            plt.ylabel("Augmented", fontsize=12)

    plt.tight_layout()
    plt.show()

show_original_vs_augmented(sample_path, seq_len=6, img_size=IMG_SIZE)

# %%
def preprocess_video(video_path, seq_len=32, img_size=128, augment=False):
    frames = uniform_frame_sampling(video_path, seq_len=seq_len, img_size=img_size)

    if augment:
        frames = augment_video_frames(frames)

    frames = frames / 255.0
    return frames.astype(np.float32)

# %%
class VideoDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, df, batch_size=4, seq_len=32, img_size=128, augment=False, shuffle=True):
        self.df = df.reset_index(drop=True).copy()
        self.batch_size = batch_size
        self.seq_len = seq_len
        self.img_size = img_size
        self.augment = augment
        self.shuffle = shuffle
        self.indices = np.arange(len(self.df))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))

    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size : (index + 1) * self.batch_size]
        batch_df = self.df.iloc[batch_indices]

        X_batch = []
        y_batch = []

        for _, row in batch_df.iterrows():
            video = preprocess_video(
                row["path"],
                seq_len=self.seq_len,
                img_size=self.img_size,
                augment=self.augment
            )
            X_batch.append(video)
            y_batch.append(row["label"])

        X_batch = np.array(X_batch, dtype=np.float32)
        y_batch = np.array(y_batch, dtype=np.float32)

        return X_batch, y_batch

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# %%
train_gen = VideoDataGenerator(
    train_df,
    batch_size=BATCH_SIZE,
    seq_len=SEQ_LEN,
    img_size=IMG_SIZE,
    augment=True,
    shuffle=True
)

val_gen = VideoDataGenerator(
    val_df,
    batch_size=BATCH_SIZE,
    seq_len=SEQ_LEN,
    img_size=IMG_SIZE,
    augment=False,
    shuffle=False
)

test_gen = VideoDataGenerator(
    test_df,
    batch_size=BATCH_SIZE,
    seq_len=SEQ_LEN,
    img_size=IMG_SIZE,
    augment=False,
    shuffle=False
)

print("Train steps:", len(train_gen))
print("Val steps  :", len(val_gen))
print("Test steps :", len(test_gen))
# Out:
# Train steps: 111
# Val steps  : 24
# Test steps : 24

# %%
X_batch, y_batch = train_gen[0]
print("X_batch:", X_batch.shape)
print("y_batch:", y_batch.shape)
print("range:", X_batch.min(), X_batch.max())
# Out:
# X_batch: (4, 32, 128, 128, 3)
# y_batch: (4,)
# range: 0.0 1.0

# %%
def show_preprocessed_video(video_tensor, num_frames=6):
    indices = np.linspace(0, len(video_tensor) - 1, num_frames).astype(int)

    plt.figure(figsize=(15, 4))
    for i, idx in enumerate(indices):
        plt.subplot(1, num_frames, i + 1)
        plt.imshow(video_tensor[idx])
        plt.title(f"Frame {idx}")
        plt.axis("off")
    plt.tight_layout()
    plt.show()

show_preprocessed_video(X_batch[0], num_frames=6)
print("Label:", y_batch[0])
# Out:
# Label: 1.0

# %% [markdown]
# #### `Model`

# %%
input_shape = (32, 128, 128, 3)

model = models.Sequential([
    layers.Conv3D(32, kernel_size=(3, 3, 3), activation='relu', padding='same', input_shape=input_shape),
    layers.MaxPooling3D(pool_size=(1, 2, 2)),

    layers.Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    layers.Dropout(0.3),
    layers.MaxPooling3D(pool_size=(2, 2, 2)),

    layers.Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    layers.Dropout(0.4),
    layers.MaxPooling3D(pool_size=(2, 2, 2)),

    layers.Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    layers.Dropout(0.4),
    layers.MaxPooling3D(pool_size=(2, 2, 2)),

    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 32, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 32, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 32, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 64, 64, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 16, 32, 32, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 16, 32, 32,     │       221,312 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 32, 32,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 8, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 8, 16, 16, 256) │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 16, 16, 256) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 4, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    33,554,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,719,745 (132.45 MB)
#  Trainable params: 34,719,745 (132.45 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='binary_crossentropy',
    metrics=['accuracy', metrics.Precision(), metrics.Recall(),metrics.AUC(name='auc')]
)

# %%
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    "model.keras",
    monitor="val_accuracy",
    mode="max",
    save_best_only=True,
    verbose=1
)
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=30,
    callbacks=[checkpoint_callback]
)
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4900 - auc: 0.4894 - loss: 0.7508 - precision: 0.5269 - recall: 0.5795
# Epoch 1: val_accuracy improved from None to 0.48936, saving model to model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 603s 5s/step - accuracy: 0.5034 - auc: 0.5134 - loss: 0.7419 - precision: 0.5091 - recall: 0.5022 - val_accuracy: 0.4894 - val_auc: 0.7043 - val_loss: 0.6919 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4534 - auc: 0.4380 - loss: 0.7265 - precision: 0.4888 - recall: 0.5966
# Epoch 2: val_accuracy improved from 0.48936 to 0.78723, saving model to model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 576s 5s/step - accuracy: 0.4921 - auc: 0.4786 - loss: 0.7144 - precision: 0.4980 - recall: 0.5561 - val_accuracy: 0.7872 - val_auc: 0.6449 - val_loss: 0.6912 - val_precision: 0.7593 - val_recall: 0.8542
# Epoch 3/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5264 - auc: 0.5105 - loss: 0.6977 - precision: 0.5182 - recall: 0.5036
# Epoch 3: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 549s 5s/step - accuracy: 0.4966 - auc: 0.4988 - loss: 0.7002 - precision: 0.5023 - recall: 0.4888 - val_accuracy: 0.5851 - val_auc: 0.7903 - val_loss: 0.6908 - val_precision: 1.0000 - val_recall: 0.1875
# Epoch 4/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5565 - auc: 0.5490 - loss: 0.6869 - precision: 0.5636 - recall: 0.7538
# Epoch 4: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 574s 5s/step - accuracy: 0.5488 - auc: 0.5452 - loss: 0.6889 - precision: 0.5432 - recall: 0.6771 - val_accuracy: 0.5000 - val_auc: 0.6726 - val_loss: 0.6907 - val_precision: 1.0000 - val_recall: 0.0208
# Epoch 5/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4840 - auc: 0.5050 - loss: 0.6952 - precision: 0.4298 - recall: 0.3573
# Epoch 5: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 586s 5s/step - accuracy: 0.5011 - auc: 0.5280 - loss: 0.6934 - precision: 0.5072 - recall: 0.4753 - val_accuracy: 0.5106 - val_auc: 0.8225 - val_loss: 0.6893 - val_precision: 0.5106 - val_recall: 1.0000
# Epoch 6/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5562 - auc: 0.5316 - loss: 0.6964 - precision: 0.5416 - recall: 0.7341
# Epoch 6: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 603s 5s/step - accuracy: 0.5125 - auc: 0.5198 - loss: 0.6952 - precision: 0.5165 - recall: 0.5605 - val_accuracy: 0.4894 - val_auc: 0.7500 - val_loss: 0.6895 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5696 - auc: 0.6102 - loss: 0.6778 - precision: 0.5924 - recall: 0.6147
# Epoch 7: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 586s 5s/step - accuracy: 0.5306 - auc: 0.5850 - loss: 0.6808 - precision: 0.5333 - recall: 0.5740 - val_accuracy: 0.4894 - val_auc: 0.9253 - val_loss: 0.6877 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5469 - auc: 0.5608 - loss: 0.6871 - precision: 0.5645 - recall: 0.3293
# Epoch 8: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 581s 5s/step - accuracy: 0.5510 - auc: 0.5843 - loss: 0.6831 - precision: 0.5698 - recall: 0.4574 - val_accuracy: 0.5106 - val_auc: 0.9244 - val_loss: 0.6844 - val_precision: 0.5106 - val_recall: 1.0000
# Epoch 9/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5675 - auc: 0.6120 - loss: 0.6817 - precision: 0.5507 - recall: 0.8605
# Epoch 9: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 564s 5s/step - accuracy: 0.5669 - auc: 0.5959 - loss: 0.6794 - precision: 0.5580 - recall: 0.6906 - val_accuracy: 0.4894 - val_auc: 0.9416 - val_loss: 0.6836 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5570 - auc: 0.6057 - loss: 0.6808 - precision: 0.5998 - recall: 0.6069
# Epoch 10: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 591s 5s/step - accuracy: 0.5873 - auc: 0.6129 - loss: 0.6772 - precision: 0.5851 - recall: 0.6323 - val_accuracy: 0.6702 - val_auc: 0.9223 - val_loss: 0.6801 - val_precision: 0.9048 - val_recall: 0.3958
# Epoch 11/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5992 - auc: 0.6464 - loss: 0.6664 - precision: 0.6397 - recall: 0.5501
# Epoch 11: val_accuracy did not improve from 0.78723
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 570s 5s/step - accuracy: 0.6259 - auc: 0.6864 - loss: 0.6601 - precision: 0.6422 - recall: 0.5874 - val_accuracy: 0.7660 - val_auc: 0.9502 - val_loss: 0.6736 - val_precision: 0.9333 - val_recall: 0.5833
# Epoch 12/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6192 - auc: 0.6747 - loss: 0.6587 - precision: 0.6738 - recall: 0.5739
# Epoch 12: val_accuracy improved from 0.78723 to 0.90426, saving model to model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 569s 5s/step - accuracy: 0.6531 - auc: 0.7080 - loss: 0.6508 - precision: 0.6750 - recall: 0.6054 - val_accuracy: 0.9043 - val_auc: 0.9563 - val_loss: 0.6671 - val_precision: 0.9333 - val_recall: 0.8750
# Epoch 13/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6256 - auc: 0.7082 - loss: 0.6340 - precision: 0.6265 - recall: 0.7097
# Epoch 13: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 569s 5s/step - accuracy: 0.6599 - auc: 0.7272 - loss: 0.6232 - precision: 0.6580 - recall: 0.6816 - val_accuracy: 0.6809 - val_auc: 0.9565 - val_loss: 0.6611 - val_precision: 0.9091 - val_recall: 0.4167
# Epoch 14/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7138 - auc: 0.7899 - loss: 0.6001 - precision: 0.6937 - recall: 0.8003
# Epoch 14: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 577s 5s/step - accuracy: 0.7029 - auc: 0.7681 - loss: 0.6040 - precision: 0.6855 - recall: 0.7623 - val_accuracy: 0.9043 - val_auc: 0.9633 - val_loss: 0.6508 - val_precision: 0.9535 - val_recall: 0.8542
# Epoch 15/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7327 - auc: 0.7882 - loss: 0.5923 - precision: 0.7340 - recall: 0.6573
# Epoch 15: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 556s 5s/step - accuracy: 0.7166 - auc: 0.7815 - loss: 0.5944 - precision: 0.7025 - recall: 0.7623 - val_accuracy: 0.8830 - val_auc: 0.9626 - val_loss: 0.6361 - val_precision: 0.9512 - val_recall: 0.8125
# Epoch 16/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7323 - auc: 0.8102 - loss: 0.5736 - precision: 0.7692 - recall: 0.6936
# Epoch 16: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 557s 5s/step - accuracy: 0.7574 - auc: 0.8292 - loss: 0.5537 - precision: 0.7871 - recall: 0.7130 - val_accuracy: 0.8936 - val_auc: 0.9644 - val_loss: 0.6183 - val_precision: 0.9130 - val_recall: 0.8750
# Epoch 17/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7267 - auc: 0.7920 - loss: 0.5610 - precision: 0.7441 - recall: 0.6699
# Epoch 17: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 626s 6s/step - accuracy: 0.7415 - auc: 0.7991 - loss: 0.5621 - precision: 0.7535 - recall: 0.7265 - val_accuracy: 0.8191 - val_auc: 0.9663 - val_loss: 0.6117 - val_precision: 0.9429 - val_recall: 0.6875
# Epoch 18/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7626 - auc: 0.8452 - loss: 0.5204 - precision: 0.7856 - recall: 0.6873
# Epoch 18: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 638s 6s/step - accuracy: 0.7664 - auc: 0.8437 - loss: 0.5215 - precision: 0.7752 - recall: 0.7578 - val_accuracy: 0.8191 - val_auc: 0.9674 - val_loss: 0.5973 - val_precision: 0.9429 - val_recall: 0.6875
# Epoch 19/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7861 - auc: 0.8704 - loss: 0.4935 - precision: 0.8012 - recall: 0.7551
# Epoch 19: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 608s 5s/step - accuracy: 0.7937 - auc: 0.8723 - loss: 0.4828 - precision: 0.7946 - recall: 0.7982 - val_accuracy: 0.8830 - val_auc: 0.9719 - val_loss: 0.5795 - val_precision: 0.8136 - val_recall: 1.0000
# Epoch 20/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7930 - auc: 0.8397 - loss: 0.5037 - precision: 0.8029 - recall: 0.7519
# Epoch 20: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 607s 5s/step - accuracy: 0.8095 - auc: 0.8757 - loss: 0.4707 - precision: 0.8145 - recall: 0.8072 - val_accuracy: 0.6915 - val_auc: 0.9719 - val_loss: 0.5719 - val_precision: 0.9130 - val_recall: 0.4375
# Epoch 21/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7768 - auc: 0.8666 - loss: 0.4766 - precision: 0.8053 - recall: 0.7364
# Epoch 21: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 626s 6s/step - accuracy: 0.8209 - auc: 0.8865 - loss: 0.4470 - precision: 0.8303 - recall: 0.8117 - val_accuracy: 0.8617 - val_auc: 0.9726 - val_loss: 0.5475 - val_precision: 0.7869 - val_recall: 1.0000
# Epoch 22/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8462 - auc: 0.9165 - loss: 0.4020 - precision: 0.8507 - recall: 0.7995
# Epoch 22: val_accuracy did not improve from 0.90426
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 652s 6s/step - accuracy: 0.8458 - auc: 0.8988 - loss: 0.4224 - precision: 0.8507 - recall: 0.8430 - val_accuracy: 0.8830 - val_auc: 0.9731 - val_loss: 0.5426 - val_precision: 0.9512 - val_recall: 0.8125
# Epoch 23/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8755 - auc: 0.9402 - loss: 0.3781 - precision: 0.8424 - recall: 0.9066
# Epoch 23: val_accuracy improved from 0.90426 to 0.91489, saving model to model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 658s 6s/step - accuracy: 0.8594 - auc: 0.9249 - loss: 0.3872 - precision: 0.8426 - recall: 0.8879 - val_accuracy: 0.9149 - val_auc: 0.9764 - val_loss: 0.5157 - val_precision: 0.9545 - val_recall: 0.8750
# Epoch 24/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8242 - auc: 0.9039 - loss: 0.4020 - precision: 0.8043 - recall: 0.8211
# Epoch 24: val_accuracy improved from 0.91489 to 0.95745, saving model to model.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 574s 5s/step - accuracy: 0.8413 - auc: 0.9191 - loss: 0.3792 - precision: 0.8370 - recall: 0.8520 - val_accuracy: 0.9574 - val_auc: 0.9776 - val_loss: 0.4908 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 25/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8735 - auc: 0.9130 - loss: 0.3879 - precision: 0.8688 - recall: 0.8896
# Epoch 25: val_accuracy did not improve from 0.95745
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 575s 5s/step - accuracy: 0.8594 - auc: 0.9214 - loss: 0.3756 - precision: 0.8610 - recall: 0.8610 - val_accuracy: 0.9574 - val_auc: 0.9792 - val_loss: 0.4745 - val_precision: 0.9231 - val_recall: 1.0000
# Epoch 26/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8424 - auc: 0.9287 - loss: 0.3621 - precision: 0.8581 - recall: 0.7876
# Epoch 26: val_accuracy did not improve from 0.95745
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 575s 5s/step - accuracy: 0.8481 - auc: 0.9282 - loss: 0.3581 - precision: 0.8645 - recall: 0.8296 - val_accuracy: 0.8617 - val_auc: 0.9814 - val_loss: 0.4844 - val_precision: 0.9487 - val_recall: 0.7708
# Epoch 27/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8670 - auc: 0.9248 - loss: 0.3399 - precision: 0.8792 - recall: 0.7946
# Epoch 27: val_accuracy did not improve from 0.95745
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 543s 5s/step - accuracy: 0.8821 - auc: 0.9363 - loss: 0.3347 - precision: 0.8834 - recall: 0.8834 - val_accuracy: 0.9574 - val_auc: 0.9853 - val_loss: 0.4432 - val_precision: 0.9400 - val_recall: 0.9792
# Epoch 28/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9010 - auc: 0.9444 - loss: 0.3085 - precision: 0.8970 - recall: 0.9004
# Epoch 28: val_accuracy did not improve from 0.95745
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 529s 5s/step - accuracy: 0.8934 - auc: 0.9433 - loss: 0.3145 - precision: 0.8826 - recall: 0.9103 - val_accuracy: 0.9574 - val_auc: 0.9882 - val_loss: 0.4254 - val_precision: 0.9231 - val_recall: 1.0000
# Epoch 29/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8473 - auc: 0.9353 - loss: 0.3335 - precision: 0.8108 - recall: 0.8793
# Epoch 29: val_accuracy did not improve from 0.95745
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 858s 8s/step - accuracy: 0.8617 - auc: 0.9361 - loss: 0.3298 - precision: 0.8403 - recall: 0.8969 - val_accuracy: 0.9574 - val_auc: 0.9898 - val_loss: 0.4241 - val_precision: 0.9231 - val_recall: 1.0000
# Epoch 30/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8830 - auc: 0.9391 - loss: 0.3207 - precision: 0.8715 - recall: 0.9012
# Epoch 30: val_accuracy did not improve from 0.95745
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 661s 6s/step - accuracy: 0.8889 - auc: 0.9412 - loss: 0.3161 - precision: 0.8884 - recall: 0.8924 - val_accuracy: 0.9574 - val_auc: 0.9909 - val_loss: 0.4108 - val_precision: 0.9231 - val_recall: 1.0000

# %%
model.save('model.keras')

# %%
best_model = load_model('model.keras')

test_results = best_model.evaluate(test_gen)

loss, accuracy, precision, recall, auc = test_results

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test AUC: {auc:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - accuracy: 0.9263 - auc: 0.9546 - loss: 0.4298 - precision: 0.8727 - recall: 1.0000
# Test Loss: 0.4298
# Test Accuracy: 0.9263
# Test Precision: 0.8727
# Test Recall: 1.0000
# Test AUC: 0.9546

# %%
plt.figure(figsize=(10, 4))
plt.plot(history.history["accuracy"], label="Train Acc")
plt.plot(history.history["val_accuracy"], label="Val Acc")
plt.title("Accuracy")
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("Loss")
plt.legend()
plt.show()

# %%
y_pred_prob = model.predict(test_gen, verbose=1).flatten()
y_pred = (y_pred_prob > 0.5).astype(np.int32)

y_true = test_df["label"].values[:len(y_pred)]

print(classification_report(
    y_true,
    y_pred,
    target_names=["non shop lifters", "shop lifters"]
))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step
#                   precision    recall  f1-score   support
#
# non shop lifters       1.00      0.85      0.92        47
#     shop lifters       0.87      1.00      0.93        48
#
#         accuracy                           0.93        95
#        macro avg       0.94      0.93      0.93        95
#     weighted avg       0.94      0.93      0.93        95

# %%
cm = confusion_matrix(y_true, y_pred)
print(cm)

plt.figure(figsize=(5,4))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix")
plt.colorbar()
plt.xticks([0,1], ["non shop", "shop"])
plt.yticks([0,1], ["non shop", "shop"])

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center", color="black")

plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# [[40  7]
#  [ 0 48]]

# %%
def predict_single_video(model, video_path, seq_len=32, img_size=128):
    video = preprocess_video(video_path, seq_len=seq_len, img_size=img_size, augment=False)
    x = np.expand_dims(video, axis=0)
    prob = model.predict(x, verbose=0)[0][0]
    label = 1 if prob > 0.5 else 0
    class_name = "shop lifters" if label == 1 else "non shop lifters"
    return prob, label, class_name

sample_video = test_df.iloc[0]["path"]
prob, label, class_name = predict_single_video(model, sample_video, seq_len=SEQ_LEN, img_size=IMG_SIZE)

print("Video:", sample_video)
print("Probability:", prob)
print("Predicted label:", label)
print("Predicted class:", class_name)
# Out:
# Video: Shop DataSet\shop lifters\shop_lifter_88.mp4
# Probability: 0.59623986
# Predicted label: 1
# Predicted class: shop lifters

# %%
def predict_single_video(model, video_path, seq_len=32, img_size=128):
    video = preprocess_video(video_path, seq_len=seq_len, img_size=img_size, augment=False)
    x = np.expand_dims(video, axis=0)
    prob = model.predict(x, verbose=0)[0][0]
    label = 1 if prob > 0.5 else 0
    class_name = "shop lifters" if label == 1 else "non shop lifters"
    return prob, label, class_name

sample_video = test_df.iloc[5]["path"]
prob, label, class_name = predict_single_video(model, sample_video, seq_len=SEQ_LEN, img_size=IMG_SIZE)

print("Video:", sample_video)
print("Probability:", prob)
print("Predicted label:", label)
print("Predicted class:", class_name)
# Out:
# Video: Shop DataSet\non shop lifters\shop_lifter_n_2.mp4
# Probability: 0.25046137
# Predicted label: 0
# Predicted class: non shop lifters
